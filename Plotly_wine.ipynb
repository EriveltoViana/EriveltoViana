# %% [markdown]
# <a href="https://colab.research.google.com/github/EriveltoViana/EriveltoViana/blob/main/Plotly_wine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
from google.colab import files
from deep_translator import GoogleTranslator

uploaded = files.upload()

import io
df = pd.read_csv(io.BytesIO(uploaded['wine.csv']))
fig = px.parallel_coordinates(df, title = "Numeric 'size' values mean continuous color",
                              dimensions=['Alcohol', 'Malic_acid', 'Ash', 'Alcalinity_ash', 'Magnesium', 'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols', 'Proanthocyanins', 'Color_intensity', 'Hue', 'OD280_OD315', 'Proline'],
                              color_continuous_scale=px.colors.diverging.Tealrose,
                              color_continuous_midpoint=2)
fig.show()
# Out:
#   File "<ipython-input-91-e1145efc1151>", line 12
#     dimensions=['Alcohol':'Álcool', 'Malic_acid', 'Ash', 'Alcalinity_ash', 'Magnesium', 'Total_phenols', 'Flavanoids', 'Nonflavanoid_phenols', 'Proanthocyanins', 'Color_intensity', 'Hue', 'OD280_OD315', 'Proline'],
#                          ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#    Alcohol  Malic_acid   Ash  Alcalinity_ash  Magnesium  Total_phenols  \
# 1    14.23        1.71  2.43            15.6        127           2.80
# 1    13.20        1.78  2.14            11.2        100           2.65
# 1    13.16        2.36  2.67            18.6        101           2.80
# 1    14.37        1.95  2.50            16.8        113           3.85
# 1    13.24        2.59  2.87            21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity   Hue  \
# 1        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 1        3.24                  0.30             2.81             5.68  1.03
# 1        3.49                  0.24             2.18             7.80  0.86
# 1        2.69                  0.39             1.82             4.32  1.04
#
#    OD280_OD315  Proline
# 1         3.92     1065
# 1         3.40     1050
# ...

# %%
print(df.describe())

# %%
fig = go.Figure()

# %%
# !ls
# Out:
# sample_data  wine.csv

# %%
# !rm wine.csv

# %%
# !ls
# Out:
# sample_data

# %%
# !rm wine.csv

# %%
import pandas as pd
import plotly.express as px
import io
from google.colab import files

def carregar_arquivo():
    uploaded = files.upload()
    for fn in uploaded.keys():
        print(f'Arquivo "{fn}" carregado com sucesso.')
    return pd.read_csv(io.BytesIO(uploaded[fn]))

dados = pd.read_csv('wine.csv')

print("Primeiras linhas dos dados:")
print(dados.head())

traducao_colunas = {
    'Alcohol': 'Álcool',
    'Malic_acid': 'Ácido_Málico',
    'Ash': 'Cinzas',
    'Alcalinity_ash': 'Alcalinidade_Cinzas',
    'Magnesium': 'Magnésio',
    'Total_phenols': 'Fenóis_Totais',
    'Flavanoids': 'Flavonóides',
    'Nonflavanoid_phenols': 'Fenóis_Não_Flavonóides',
    'Proanthocyanins': 'Proantocianinas',
    'Color_intensity': 'Intensidade_Cor',
    'Hue': 'Tonalidade',
    'OD280_OD315': 'OD280_OD315',
    'Proline': 'Prolina'
}

# Renomear as colunas
dados = dados.rename(columns=traducao_colunas)

# Adicionar nomes descritivos para as classes
mapeamento_classes = {1: 'Tipo 1', 2: 'Tipo 2', 3: 'Tipo 3'}
dados['Classe'] = dados.iloc[:, 0].map(mapeamento_classes)

# Criar a visualização de coordenadas paralelas com Plotly
# Usando a Intensidade_Cor como atributo para a escala de cores
fig = px.parallel_coordinates(
    dados,
    color="Intensidade_Cor",
    dimensions=dados.columns[1:-1],  # Exclui a primeira coluna (classe original) e a última (Classe renomeada)
    color_continuous_scale=px.colors.sequential.Blues,
    title="Visualização de Coordenadas Paralelas com Intensidade de Cor"
)

# Personalizar o layout
fig.update_layout(
    font=dict(size=12),
    height=600,
    width=1200,
)

# Exibir o gráfico
fig.show()

# Salvar a visualização como HTML (opcional)
fig.write_html('visualizacao_coordenadas_paralelas.html')
files.download('visualizacao_coordenadas_paralelas.html')

# Visualização alternativa agrupada por classe
fig_classe = px.parallel_coordinates(
    dados,
    color="Classe",
    dimensions=dados.columns[1:-1],
    title="Visualização de Coordenadas Paralelas por Tipo de Vinho"
)

fig_classe.update_layout(
    font=dict(size=12),
    height=600,
    width=1200,
)

fig_classe.show()
# Out:
# Primeiras linhas dos dados:
#    Alcohol  Malic_acid   Ash  Alcalinity_ash  Magnesium  Total_phenols  \
# 1    14.23        1.71  2.43            15.6        127           2.80
# 1    13.20        1.78  2.14            11.2        100           2.65
# 1    13.16        2.36  2.67            18.6        101           2.80
# 1    14.37        1.95  2.50            16.8        113           3.85
# 1    13.24        2.59  2.87            21.0        118           2.80
#
#    Flavanoids  Nonflavanoid_phenols  Proanthocyanins  Color_intensity   Hue  \
# 1        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 1        3.24                  0.30             2.81             5.68  1.03
# 1        3.49                  0.24             2.18             7.80  0.86
# 1        2.69                  0.39             1.82             4.32  1.04
#
#    OD280_OD315  Proline
# 1         3.92     1065
# ...
